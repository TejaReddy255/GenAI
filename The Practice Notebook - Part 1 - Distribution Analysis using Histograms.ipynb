# %% [markdown]
# # Welcome To The Practice Notebook
# ---

# %% [markdown]
# Importing the pandas library

# %%
import pandas as pd

# %% [markdown]
# Import the json Imdb Dataset

# %%
# Your code goes here
jdf=pd.read_json('movies_dataset.json')

# %% [markdown]
# Answer to the following Analytical questions:
#
# Question 1: Use Histograms to compare the disribution of movie `imdb_score` column related to movies produced in `France` and `Canada`.
#
# While creating the histgoram:
# - Set the number of bins to 20
# - Set the xAxis Label
# - Set the yAxis Label
# - Remove the grid lines

# %%
# Create the histogram for Canada here 
ax=jdf[jdf.country=='Canada'].imdb_score.hist(bins=20,grid=False)
ax.set_xlabel('imdb score of movies')
ax.set_ylabel('count')
ax.set_title('Canada Imdb score')
# Out:
# Text(0.5, 1.0, 'Canada Imdb score')

# %%
# Create the histogram for France here 
ax=jdf[jdf.country=='France'].imdb_score.hist(bins=20,grid=False)
ax.set_xlabel('imdb score of movies')
ax.set_ylabel('count')
ax.set_title('France Imdb score')
# Out:
# Text(0.5, 1.0, 'France Imdb score')

# %% [markdown]
# Question 2: Create a histogram to check the distribution of `imdb_score` spent to produce Black&White movies.
#
# While creating the histgoram:
# - Set the number of bins to 10
# - Set the xAxis Label
# - Set the yAxis Label
# - Remove the grid lines

# %%
#To go back to the tree, click on the Jupyter icon
ax=jdf[jdf.color=='Black and White'] .budget.hist(grid=False ,bins=10)
ax.set_title('B&W Movies budget histragram')
ax.set_xlabel('Budget')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')
