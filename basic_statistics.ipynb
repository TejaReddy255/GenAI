1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import  pandas as pd

# %%
st_data_2018=pd.read_csv("data/science_tech_2018.csv")
st_data_2018
# Out:
#            Country Name  High-technology exports (% of manufactured exports)  \
# 0           Afghanistan                                                NaN
# 1               Albania                                           0.049514
# 2               Algeria                                                NaN
# 3        American Samoa                                                NaN
# 4               Andorra                                          28.460560
# ..                  ...                                                ...
# 214  West Bank and Gaza                                           0.850016
# 215               World                                          20.781626
# 216         Yemen, Rep.                                                NaN
# 217              Zambia                                           1.998840
# 218            Zimbabwe                                           2.050870
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 0                                      NaN                            NaN
# 1                                 591717.0                         3713.0
# 2                                      NaN                         9490.0
# 3                                      NaN                            NaN
# 4                               33913480.0                         1180.0
# ..                                     ...                            ...
# 214                              6243920.0                            NaN
# 215                                    NaN                      3617130.0
# 216                                    NaN                         5799.0
# 217                             25805507.0                            NaN
# 218                              9719357.0                            NaN
#
#      Trademark applications, direct resident  \
# 0                                        NaN
# 1                                      917.0
# 2                                     5469.0
# 3                                        NaN
# 4                                      256.0
# ..                                       ...
# 214                                      NaN
# 215                                2585202.0
# 216                                   4044.0
# 217                                      NaN
# 218                                      NaN
#
#      Trademark applications, direct nonresident  \
# 0                                           NaN
# 1                                        2796.0
# 2                                        4021.0
# 3                                           NaN
# 4                                         924.0
# ..                                          ...
# 214                                         NaN
# 215                                   1008650.0
# 216                                      1755.0
# 217                                         NaN
# 218                                         NaN
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 0                               NaN                                NaN
# 1                              15.0                                3.0
# 2                             152.0                              521.0
# 3                               NaN                                NaN
# 4                               1.0                               10.0
# ..                              ...                                ...
# 214                             NaN                                NaN
# 215                       2294847.0                           845358.0
# 216                             NaN                                NaN
# 217                             NaN                                NaN
# 218                             NaN                                NaN
#
#      Scientific and technical journal articles  \
# 0                                 1.117200e+02
# 1                                 1.803600e+02
# 2                                 5.231440e+03
# 3                                          NaN
# 4                                 3.600000e+00
# ..                                         ...
# 214                               3.759500e+02
# 215                               2.554373e+06
# 216                               1.374400e+02
# 217                               2.130700e+02
# 218                               3.593300e+02
#
#      Research and development expenditure (% of GDP)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 214                                              NaN
# 215                                          2.27364
# 216                                              NaN
# 217                                              NaN
# 218                                              NaN
#
# [219 rows x 10 columns]

# %%
st_data_2018.shape
# Out:
# (219, 10)

# %%
st_data_2018.size
# Out:
# 2190

# %%
st_data_2018.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
st_data_2009=pd.read_csv('data/science_tech_2009.csv')

# %%
st_data_2009.shape
# Out:
# (219, 10)

# %%
st_data_2009
# Out:
#            Country Name  High-technology exports (% of manufactured exports)  \
# 0           Afghanistan                                                NaN
# 1               Albania                                           1.328024
# 2               Algeria                                           0.653887
# 3        American Samoa                                                NaN
# 4               Andorra                                          12.192161
# ..                  ...                                                ...
# 214  West Bank and Gaza                                           0.127454
# 215               World                                          21.165688
# 216         Yemen, Rep.                                           0.380686
# 217              Zambia                                           1.762955
# 218            Zimbabwe                                           3.344684
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 0                                      NaN                            NaN
# 1                               10128935.0                         3456.0
# 2                                4616076.0                         5345.0
# 3                                      NaN                            NaN
# 4                               10402350.0                          785.0
# ..                                     ...                            ...
# 214                               358718.0                            NaN
# 215                                    NaN                      3098078.0
# 216                               382625.0                         3730.0
# 217                              6210779.0                         1787.0
# 218                              9071079.0                            NaN
#
#      Trademark applications, direct resident  \
# 0                                        NaN
# 1                                      213.0
# 2                                        NaN
# 3                                        NaN
# 4                                      243.0
# ..                                       ...
# 214                                      NaN
# 215                                2365446.0
# 216                                      NaN
# 217                                    524.0
# 218                                      NaN
#
#      Trademark applications, direct nonresident  \
# 0                                           NaN
# 1                                        3243.0
# 2                                           NaN
# 3                                           NaN
# 4                                         542.0
# ..                                          ...
# 214                                         NaN
# 215                                    675346.0
# 216                                         NaN
# 217                                      1263.0
# 218                                         NaN
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 0                               NaN                                NaN
# 1                               NaN                              361.0
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
# ..                              ...                                ...
# 214                             NaN                                NaN
# 215                       1075376.0                           633454.0
# 216                             NaN                                NaN
# 217                             9.0                                9.0
# 218                             NaN                                NaN
#
#      Scientific and technical journal articles  \
# 0                                 2.630000e+01
# 1                                 7.035000e+01
# 2                                 2.135320e+03
# 3                                          NaN
# 4                                 2.550000e+00
# ..                                         ...
# 214                               1.807200e+02
# 215                               1.853967e+06
# 216                               8.394000e+01
# 217                               7.652000e+01
# 218                               1.171400e+02
#
#      Research and development expenditure (% of GDP)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 214                                         0.396550
# 215                                         2.034221
# 216                                              NaN
# 217                                              NaN
# 218                                              NaN
#
# [219 rows x 10 columns]

# %%
print(st_data_2009.columns)
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# ### Missing Data

# %%
st_data_2018.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     87
# High-technology exports (current US$)                   88
# Trademark applications, total                           86
# Trademark applications, direct resident                 91
# Trademark applications, direct nonresident              90
# Patent applications, residents                         101
# Patent applications, nonresidents                      100
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        146
# dtype: int64

# %%
st_data_2018_clean=st_data_2018.dropna()

# %%
st_data_2018_clean.shape
# Out:
# (51, 10)

# %%
st_data_2009.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     88
# High-technology exports (current US$)                   88
# Trademark applications, total                          108
# Trademark applications, direct resident                118
# Trademark applications, direct nonresident             118
# Patent applications, residents                         126
# Patent applications, nonresidents                      118
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        122
# dtype: int64

# %%
st_data_2009_clean=st_data_2009.dropna()

# %%
st_data_2009_clean.shape
# Out:
# (56, 10)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ###  Descriptive Statstics

# %%
pd.set_option('display.float_format',lambda x:'%.3f'%x)
st_data_2018_clean.describe().style.format('{:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7939b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7939b_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_7939b_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_7939b_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_7939b_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_7939b_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_7939b_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_7939b_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
#       <th id="T_7939b_level0_col7" class="col_heading level0 col7" >Scientific and technical journal articles</th>
#       <th id="T_7939b_level0_col8" class="col_heading level0 col8" >Research and development expenditure (% of GDP)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7939b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_7939b_row0_col0" class="data row0 col0" >51</td>
#       <td id="T_7939b_row0_col1" class="data row0 col1" >51</td>
#       <td id="T_7939b_row0_col2" class="data row0 col2" >51</td>
#       <td id="T_7939b_row0_col3" class="data row0 col3" >51</td>
#       <td id="T_7939b_row0_col4" class="data row0 col4" >51</td>
#       <td id="T_7939b_row0_col5" class="data row0 col5" >51</td>
#       <td id="T_7939b_row0_col6" class="data row0 col6" >51</td>
#       <td id="T_7939b_row0_col7" class="data row0 col7" >51</td>
#       <td id="T_7939b_row0_col8" class="data row0 col8" >51</td>
#     </tr>
#     <tr>
#       <th id="T_7939b_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_7939b_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_7939b_row1_col1" class="data row1 col1" >25,697,867,097</td>
#       <td id="T_7939b_row1_col2" class="data row1 col2" >44,515</td>
#       <td id="T_7939b_row1_col3" class="data row1 col3" >33,921</td>
#       <td id="T_7939b_row1_col4" class="data row1 col4" >10,594</td>
#       <td id="T_7939b_row1_col5" class="data row1 col5" >16,828</td>
#       <td id="T_7939b_row1_col6" class="data row1 col6" >11,187</td>
#       <td id="T_7939b_row1_col7" class="data row1 col7" >30,499</td>
#       <td id="T_7939b_row1_col8" class="data row1 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7939b_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_7939b_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_7939b_row2_col1" class="data row2 col1" >48,690,230,336</td>
#       <td id="T_7939b_row2_col2" class="data row2 col2" >85,394</td>
#       <td id="T_7939b_row2_col3" class="data row2 col3" >69,219</td>
#       <td id="T_7939b_row2_col4" class="data row2 col4" >18,797</td>
#       <td id="T_7939b_row2_col5" class="data row2 col5" >56,775</td>
#       <td id="T_7939b_row2_col6" class="data row2 col6" >44,725</td>
#       <td id="T_7939b_row2_col7" class="data row2 col7" >65,091</td>
#       <td id="T_7939b_row2_col8" class="data row2 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_
}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_aed88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aed88_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_aed88_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_aed88_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_aed88_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_aed88_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_aed88_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_aed88_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
#       <th id="T_aed88_level0_col7" class="col_heading level0 col7" >Scientific and technical journal articles</th>
#       <th id="T_aed88_level0_col8" class="col_heading level0 col8" >Research and development expenditure (% of GDP)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aed88_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_aed88_row0_col0" class="data row0 col0" >56</td>
#       <td id="T_aed88_row0_col1" class="data row0 col1" >56</td>
#       <td id="T_aed88_row0_col2" class="data row0 col2" >56</td>
#       <td id="T_aed88_row0_col3" class="data row0 col3" >56</td>
#       <td id="T_aed88_row0_col4" class="data row0 col4" >56</td>
#       <td id="T_aed88_row0_col5" class="data row0 col5" >56</td>
#       <td id="T_aed88_row0_col6" class="data row0 col6" >56</td>
#       <td id="T_aed88_row0_col7" class="data row0 col7" >56</td>
#       <td id="T_aed88_row0_col8" class="data row0 col8" >56</td>
#     </tr>
#     <tr>
#       <th id="T_aed88_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_aed88_row1_col0" class="data row1 col0" >15</td>
#       <td id="T_aed88_row1_col1" class="data row1 col1" >26,983,628,831</td>
#       <td id="T_aed88_row1_col2" class="data row1 col2" >49,843</td>
#       <td id="T_aed88_row1_col3" class="data row1 col3" >40,669</td>
#       <td id="T_aed88_row1_col4" class="data row1 col4" >9,173</td>
#       <td id="T_aed88_row1_col5" class="data row1 col5" >18,743</td>
#       <td id="T_aed88_row1_col6" class="data row1 col6" >10,847</td>
#       <td id="T_aed88_row1_col7" class="data row1 col7" >30,421</td>
#       <td id="T_aed88_row1_col8" class="data row1 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aed88_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_aed88_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_aed88_row2_col1" class="data row2 col1" >58,687,616,358</td>
#       <td id="T_aed88_row2_col2" class="data row2 col2" >114,676</td>
#       <td id="T_aed88_row2_col3" class="data row2 col3" >105,257</td>
#       <td id="T_aed88_row2_col4" class="data row2 col4" >10,702</td>
#       <td id="T_aed88_row2_col5" class="data row2 col5" >58,855</td>
#       <td id="T_aed88_row2_col6" class="data row2 col6" >33,561</td>
#       <td id="T_aed88_row2_col7" class="data row2 col7" >67,078</td>
#       <td id="T_aed88_row2_col8" class="data row2 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aed88_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_aed88_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_aed88_row3_col1" class="data row3 col1" >4,537,422</td>
#       <td id="T_aed88_row3_col2" class="data row3 col2" >911</td>
#       <td id="T_aed88_row3_col3" class="data row3 col3" >446</td>
#       <td id="T_aed88_row3_col4" class="data row3 col4" >465</td>
#       <td id="T_aed88_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_aed88_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_aed88_row3_col7" class="data row3 col7" >54</td>
#       <td id="T_aed88_row3_col8" class="data row3 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_aed88_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_aed88_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_aed88_row4_col1" class="data row4 col1" >514,534,600</td>
#       <td id="T_aed88_row4_col2" class="data row4 col2" >6,095</td>
#       <td id="T_aed88_row4_col3" class="data row4 col3" >2,598</td>
#       <td id="T_aed88_row4_col4" class="data row4 col4" >2,936</td>
#       <td id="T_aed88_row4_col5" class="data row4 col5" >242</td>
#       <td id="T_aed88_row4_col6" class="data row4 col6" >45</td>
#       <td id="T_aed88_row4_col7" class="data row4 col7" >2,020</td>
#       <td id="T_aed88_row4_col8" class="data row4 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_aed88_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_aed88_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_aed88_row5_col1" class="data row5 col1" >4,063,042,924</td>
#       <td id="T_aed88_row5_col2" class="data row5 col2" >14,560</td>
#       <td id="T_aed88_row5_col3" class="data row5 col3" >8,744</td>
#       <td id="T_aed88_row5_col4" class="data row5 col4" >5,674</td>
#       <td id="T_aed88_row5_col5" class="data row5 col5" >924</td>
#       <td id="T_aed88_row5_col6" class="data row5 col6" >392</td>
#       <td id="T_aed88_row5_col7" class="data row5 col7" >8,399</td>
#       <td id="T_aed88_row5_col8" class="data row5 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aed88_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_aed88_row6_col0" class="data row6 col0" >21</td>
#       <td id="T_aed88_row6_col1" class="data row6 col1" >20,547,291,738</td>
#       <td id="T_aed88_row6_col2" class="data row6 col2" >42,294</td>
#       <td id="T_aed88_row6_col3" class="data row6 col3" >29,086</td>
#       <td id="T_aed88_row6_col4" class="data row6 col4" >10,500</td>
#       <td id="T_aed88_row6_col5" class="data row6 col5" >3,073</td>
#       <td id="T_aed88_row6_col6" class="data row6 col6" >5,518</td>
#       <td id="T_aed88_row6_col7" class="data row6 col7" >26,997</td>
#       <td id="T_aed88_row6_col8" class="data row6 col8" >2</td>
#     </tr>
#     <tr>
#       <th id="T_aed88_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_aed88_row7_col0" class="data row7 col0" >51</td>
#       <td id="T_aed88_row7_col1" class="data row7 col1" >359,273,932,009</td>
#       <td id="T_aed88_row7_col2" class="data row7 col2" >806,906</td>
#       <td id="T_aed88_row7_col3" class="data row7 col3" >741,785</td>
#       <td id="T_aed88_row7_col4" class="data row7 col4" >65,121</td>
#       <td id="T_aed88_row7_col5" class="data row7 col5" >295,315</td>
#       <td id="T_aed88_row7_col6" class="data row7 col6" >231,194</td>
#       <td id="T_aed88_row7_col7" class="data row7 col7" >399,350</td>
#       <td id="T_aed88_row7_col8" class="data row7 col8" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.boxplot(x=st_data_2009_clean['High-technology exports (% of manufactured exports)'])
# Out:
# <Axes: xlabel='High-technology exports (% of manufactured exports)'>

# %% [markdown]
# ## Outlier

# %%
col=st_data_2018_clean.columns
col
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
for i in range(1,len(col)):
    fig=plt.figure(figsize=(10,5))
    sns.boxplot(x=st_data_2018_clean[col[i]])

# %%
artmax=st_data_2018_clean['Scientific and technical journal articles'].max()

# %%
st_data_2018_clean[st_data_2018_clean['Scientific and technical journal articles']==artmax]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                       156365524736.000                     464786.000
#
#      Trademark applications, direct resident  \
# 207                               342150.000
#
#      Trademark applications, direct nonresident  \
# 207                                  122636.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                      285095.000                         312046.000
#
#      Scientific and technical journal articles  \
# 207                                 422807.710
#
#      Research and development expenditure (% of GDP)
# 207                                            2.838

# %%
st_data_2018_clean[st_data_2018_clean['Scientific and technical journal articles']>60000]
# Out:
#            Country Name  High-technology exports (% of manufactured exports)  \
# 68               France                                             25.920
# 73              Germany                                             15.778
# 89                India                                              9.008
# 96                Italy                                              7.505
# 98                Japan                                             17.268
# 104         Korea, Rep.                                             36.347
# 161  Russian Federation                                             10.963
# 206      United Kingdom                                             22.643
# 207       United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 68                        117814412441.000                      98279.000
# 73                        210082307180.000                      75236.000
# 89                         20273090235.000                     323970.000
# 96                         32581025234.000                      42580.000
# 98                        111020443595.000                     183657.000
# 104                       192789656676.000                     199476.000
# 161                        10183007833.000                      75081.000
# 206                        76926541023.000                      94915.000
# 207                       156365524736.000                     464786.000
#
#      Trademark applications, direct resident  \
# 68                                 90581.000
# 73                                 65686.000
# 89                                297750.000
# 96                                 37320.000
# 98                                145269.000
# 104                               170541.000
# 161                                49132.000
# 206                                66833.000
# 207                               342150.000
#
#      Trademark applications, direct nonresident  \
# 68                                     7698.000
# 73                                     9550.000
# 89                                    26220.000
# 96                                     5260.000
# 98                                    38388.000
# 104                                   28935.000
# 161                                   25949.000
# 206                                   28082.000
# 207                                  122636.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 68                        14303.000                           1919.000
# 73                        46617.000                          21281.000
# 89                        16289.000                          33766.000
# 96                         8921.000                            900.000
# 98                       253630.000                          59937.000
# 104                      162561.000                          47431.000
# 161                       24926.000                          13031.000
# 206                       12865.000                           8076.000
# 207                      285095.000                         312046.000
#
#      Scientific and technical journal articles  \
# 68                                   66352.180
# 73                                  104396.120
# 89                                  135787.790
# 96                                   71240.280
# 98                                   98792.500
# 104                                  66376.170
# 161                                  81579.360
# 206                                  97680.900
# 207                                 422807.710
#
#      Research and development expenditure (% of GDP)
# 68                                             2.200
# 73                                             3.094
# 89                                             0.650
# 96                                             1.399
# 98                                             3.265
# 104                                            4.810
# 161                                            0.990
# 206                                            1.724
# 207                                            2.838

# %%
col2009=st_data_2009.columns

# %%
for i in range(1,len(col2009)):
    plt.figure(figsize=(10,5))
    sns.boxplot(x=st_data_2009_clean[col2009[i]])

# %% [markdown]
# ## Exploring Relationship

# %%
artmax09=st_data_2009_clean['Scientific and technical journal articles'].max()

# %%
st_data_2009_clean[st_data_2009_clean['Scientific and technical journal articles']==artmax09]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                             25.010
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                       154108484413.000                     265943.000
#
#      Trademark applications, direct resident  \
# 207                               225045.000
#
#      Trademark applications, direct nonresident  \
# 207                                   40898.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                      224912.000                         231194.000
#
#      Scientific and technical journal articles  \
# 207                                 399350.310
#
#      Research and development expenditure (% of GDP)
# 207                                            2.813

# %%
st_data_2009_clean[st_data_2009_clean['Scientific and technical journal articles']>60000]
# Out:
#        Country Name  High-technology exports (% of manufactured exports)  \
# 41            China                                             31.952
# 68           France                                             24.380
# 73          Germany                                             16.882
# 98            Japan                                             20.586
# 178      South Asia                                              8.310
# 206  United Kingdom                                             20.804
# 207   United States                                             25.010
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 41                        359273932009.000                     806906.000
# 68                         88872522741.000                      83901.000
# 73                        159207939862.000                      74370.000
# 98                        104428943952.000                     109614.000
# 178                        11674908636.000                     171910.000
# 206                        49442450948.000                      33846.000
# 207                       154108484413.000                     265943.000
#
#      Trademark applications, direct resident  \
# 41                                741785.000
# 68                                 76540.000
# 73                                 65723.000
# 98                                 90473.000
# 178                               157299.000
# 206                                25182.000
# 207                               225045.000
#
#      Trademark applications, direct nonresident  \
# 41                                    65121.000
# 68                                     7361.000
# 73                                     8647.000
# 98                                    19141.000
# 178                                   14611.000
# 206                                    8664.000
# 207                                   40898.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 41                       229096.000                          85508.000
# 68                        14100.000                           1593.000
# 73                        47859.000                          11724.000
# 98                       295315.000                          53281.000
# 178                        7519.000                          27500.000
# 206                       15985.000                           6480.000
# 207                      224912.000                         231194.000
#
#      Scientific and technical journal articles  \
# 41                                  286371.910
# 68                                   68273.770
# 73                                   95453.200
# 98                                  109131.250
# 178                                  61863.100
# 206                                  93803.370
# 207                                 399350.310
#
#      Research and development expenditure (% of GDP)
# 41                                             1.665
# 68                                             2.212
# 73                                             2.726
# 98                                             3.231
# 178                                            0.786
# 206                                            1.683
# 207                                            2.813

# %% [markdown]
# ### correlations

# %%
st_data_2018_clean.corr(method='pearson').style.background_gradient(cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 st_data_2018_clean.corr(method='pearson').style.background_gradient(cmap='viridis')
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Armenia'

# %%
st_data_2018_clean.corr(method='spearman').style.background_gradient(cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 st_data_2018_clean.corr(method='spearman').style.background_gradient(cmap='viridis')
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Armenia'

# %%
st_data_2018_clean.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2018_nonUs=st_data_2018_clean[st_data_2018_clean['Country Name'] != 'United States']

# %%
st_data_2018_nonUs.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2009_clean.corr(method='pearson').style.background_gradient(cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 st_data_2009_clean.corr(method='pearson').style.background_gradient(cmap='viridis')
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Argentina'

# %%
st_data_2018_clean.corr(method='spearman').style.background_gradient(cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 st_data_2018_clean.corr(method='spearman').style.background_gradient(cmap='viridis')
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\annem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Armenia'

# %%
st_data_2009_clean.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2009_nonUs=st_data_2009_clean[st_data_2009_clean['Country Name'] != 'United States']

# %%
st_data_2009_nonUs.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2009_nonUs.plot.scatter(x='Patent applications, nonresidents', y='High-technology exports (% of manufactured exports)')
# Out:
# <AxesSubplot: xlabel='Patent applications, nonresidents', ylabel='High-technology exports (% of manufactured exports)'>

# %%
import scipy.stats as stats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 import scipy.stats as stats
#
# ModuleNotFoundError: No module named 'scipy'

# %%
a=st_data_2009_clean['Patent applications, residents']
b=st_data_2018_clean['Patent applications, residents']
stats.ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=0.17093628150351461, pvalue=0.8646028361752646)

# %%
for i in range(1,len(col)):
    a=st_data_2009_clean[col[i]]
    b=st_data_2018_clean[col[i]]
    statistics,pvalue=stats.ttest_ind(a,b)
    if pvalue<0.05:
        s='significant'
    else:
        s='non significant'
    print(f'{col[i]} : \n \tstatistic:{statistics} \n\tpvalue:{pvalue} \n\t{s}')
# Out:
# High-technology exports (% of manufactured exports) :
#  	statistic:1.5178124850425097
# 	pvalue:0.13206686889029143
# 	non significant
# High-technology exports (current US$) :
#  	statistic:0.12265583290103693
# 	pvalue:0.902614099731734
# 	non significant
# Trademark applications, total :
#  	statistic:0.2704033385824462
# 	pvalue:0.7873807591420726
# 	non significant
# Trademark applications, direct resident :
#  	statistic:0.38774421679415133
# 	pvalue:0.6989902537733603
# 	non significant
# Trademark applications, direct nonresident :
#  	statistic:-0.48589263440463604
# 	pvalue:0.628055750890876
# 	non significant
# Patent applications, residents :
#  	statistic:0.17093628150351461
# 	pvalue:0.8646028361752646
# 	non significant
# Patent applications, nonresidents :
#  	statistic:-0.04471790792368344
# 	pvalue:0.9644170934929569
# 	non significant
# Scientific and technical journal articles :
#  	statistic:-0.006105403997445266
# 	pvalue:0.9951402075104707
# 	non significant
# Research and development expenditure (% of GDP) :
#  	statistic:-0.27962305489587264
# 	pvalue:0.7803167965750043
# 	non significant
